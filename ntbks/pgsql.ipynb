# %%
import pandas as pd
import os
import glob
import psycopg2

# %%
dfiles = glob.glob(os.path.join('../data/',"*.csv"))
dfiles = [d[8:] for d in dfiles]

# %%
dfiles
# Out:
# ['department.csv',
#  'diagnosis.csv',
#  'icdtenexc.csv',
#  'labs.csv',
#  'medications.csv',
#  'operations.csv',
#  'parameters.csv',
#  'schema.csv',
#  'vitals.csv',
#  'ward_vitals.csv']

# %%
for file in dfiles:
  tot = pd.read_csv(f"../data/{file}", open)

# %%
# dept = pd.read_csv("../data/department.csv")
# icdtenexc = pd.read_csv("../data/icdtenexc.csv")
# paramts = pd.read_csv("../data/parameters.csv")
# oper = pd.read_csv("../data/operations.csv")
# diag = pd.read_csv("../data/diagnosis.csv")
# medic = pd.read_csv("../data/medications.csv")
# labs = pd.read_csv("../data/labs.csv")
# wardv = pd.read_csv("../data/ward_vitals.csv")
# vitals = pd.read_csv("../data/vitals.csv")

# %%
# conn = psycopg2.connect(
#     dbname="inspire",
#     user="postgres",
#     password="postgres",
#     host="localhost",
#     port="5432"
# )
# cur = conn.cursor()

# conn.rollback()
# cur.execute("DROP TABLE IF EXISTS medic;")

# # Auto-create schema using pandas dtypes
# schema_parts = []
# for col, dtype in medic.dtypes.items():
#     if str(dtype).startswith("int"):
#         schema_parts.append(f'"{col}" INTEGER')
#     elif str(dtype).startswith("float"):
#         schema_parts.append(f'"{col}" DOUBLE PRECISION')
#     else:
#         schema_parts.append(f'"{col}" TEXT')

# schema = ", ".join(schema_parts)
# cur.execute(f"CREATE TABLE medic ({schema});")

# # Insert rows
# for _, row in medic.iterrows():
#     placeholders = ", ".join(["%s"] * len(row))
#     cur.execute(
#         f"INSERT INTO medic VALUES ({placeholders})",
#         tuple(row)
#     )

# conn.commit()
# cur.close()
# conn.close()

# print("Done!")
